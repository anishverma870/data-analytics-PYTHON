# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\anish\\OneDrive\\Documents\\GitHub\\data-analytics-PYTHON\\library\\pandas'

# %%
import pandas as pd

# %%
cars = pd.read_csv('carprices2.csv')

# %%
movie = pd.read_csv('User_Movie_Ratings (2).csv')

# %%
cars
# Out:
#      car_ID  symboling                   carname doornumber      carbody  \
# 0         1          3        alfa-romero giulia        two  convertible
# 1         2          3       alfa-romero stelvio        two  convertible
# 2         3          1  alfa-romero Quadrifoglio        two    hatchback
# 3         4          2               audi 100 ls       four        sedan
# 4         5          2                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 200     201         -1           volvo 145e (sw)       four        sedan
# 201     202         -1               volvo 144ea       four        sedan
# 202     203         -1               volvo 244dl       four        sedan
# 203     204         -1                 volvo 246       four        sedan
# 204     205         -1               volvo 264gl       four        sedan
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# ...

# %%
movie
# Out:
#          User  Thor  Justice League  Spiderman  The Notebook  Casablanca  \
# 0      Arnold     6               5          6             4           5
# 1         Ben     9              10          8             3           1
# 2   Catherine    10               8          9             5           6
# 3       Disha     6               7          7            10           9
# 4      Euclid     7               4          3             5           8
# 5     Farhaan     6               5          9             4           4
# 6      Gaurav     8               8          9             3           1
# 7     Hilbert     6               5          8             6           5
# 8      Indira    10               7          9             5           6
# 9       Jason    10               9          9             7           4
# 10      Kenny     3               2          5             9           8
# 11    Lambert     5               6          4            10           9
# ...

# %%
movie[['Thor','Spiderman','Casablanca']]
# Out:
#     Thor  Spiderman  Casablanca
# 0      6          6           5
# 1      9          8           1
# 2     10          9           6
# 3      6          7           9
# 4      7          3           8
# 5      6          9           4
# 6      8          9           1
# 7      6          8           5
# 8     10          9           6
# 9     10          9           4
# 10     3          5           8
# 11     5          4           9
# 12     7          6           6
# 13     3          2           8
# 14     4          4           2
# 15     8          8           1
# 16     8          8           4
# 17     8          9           9
# 18     5          6           1
# 19     1          4           6

# %%
cars.loc[78,'carname']
# Out:
# 'mitsubishi outlander'

# %%
print(movie.index)
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
movie.loc[8,'Annabelle']
# Out:
# np.int64(6)

# %%
movie.loc[[12,17], 'Thor':'Spiderman']
# Out:
#     Thor  Justice League  Spiderman
# 12     7               6          6
# 17     8               7          9

# %%
len(cars[cars['carbody'] == 'sedan'])
# Out:
# 96

# %% [markdown]
# If you take the mean rating as a popularity measure, which one of the following can be used to find the name of the most popular movie?

# %%
movie.describe().transpose()['mean'].idxmax()
# Out:
# 'Spiderman'

# %%
how to find value count

# %%
cars['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %% [markdown]
# calculates the mean for each row in the DataFrame df_movies.

# %%
movie.select_dtypes(include = 'number').mean(axis = 0)
# Out:
# Thor                    6.50
# Justice League          6.10
# Spiderman               6.65
# The Notebook            5.60
# Casablanca              5.15
# Beauty and the Beast    5.55
# Dolittle                6.15
# The Kissing Booth       5.70
# Annabelle               5.40
# Insidious               5.55
# dtype: float64

# %%
movie = movie.transpose()

# %%
movie
# Out:
#          User Thor Justice League Spiderman The Notebook Casablanca  \
# 0      Arnold    6              5         6            4          5
# 1         Ben    9             10         8            3          1
# 2   Catherine   10              8         9            5          6
# 3       Disha    6              7         7           10          9
# 4      Euclid    7              4         3            5          8
# 5     Farhaan    6              5         9            4          4
# 6      Gaurav    8              8         9            3          1
# 7     Hilbert    6              5         8            6          5
# 8      Indira   10              7         9            5          6
# 9       Jason   10              9         9            7          4
# 10      Kenny    3              2         5            9          8
# 11    Lambert    5              6         4           10          9
# 12     Manish    7              6         6            5          6
# ...

# %%
def corrections(row): 
    return 'good' if row > 5 else 'bad'
new_df = movie.select_dtypes(include = 'number').applymap(corrections)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_10716\3394191305.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   new_df = movie.select_dtypes(include = 'number').applymap(corrections)

# %% [markdown]
# Select the option that contains the operation that helps you determine which car body type mostly has two doors in the df_cars dataframe grouped by the type of car body.

# %%
cars.groupby('carbody')['doornumber'].apply(len).idxmax()
# Out:
# 'sedan'

# %% [markdown]
# How can you summarise the dataframe df_cars by grouping it based on the type of car body and calculating the median price and mean horsepower for each group?

# %%
cars.groupby('carbody').aggregate({'price': 'median', 'horsepower': 'mean'})
# Out:
#                price  horsepower
# carbody
# convertible  17084.5  131.666667
# hardtop      19687.5  142.250000
# hatchback     8897.0  101.171429
# sedan        10846.5  103.104167
# wagon        11694.0   97.440000

# %% [markdown]
# The indices are 0-N Numbers for the df_cars dataset.
# Now if you want to access df_cars columns by car_ID, what will be your approach?

# %%
# car.set_index('Car_ID', inplace=True)
