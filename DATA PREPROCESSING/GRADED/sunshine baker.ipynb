# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\anish\\OneDrive\\Documents\\GitHub\\data-analytics-PYTHON\\DATA PREPROCESSING\\GRADED'

# %%
bake  = pd.read_csv('Bakery.csv')
bake2 = pd.read_csv('bakery_sales_revised.csv')

# %%
bake
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 2                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [20507 rows x 5 columns]

# %%
scat = bake.groupby('Daypart')['Items'].count()

# %%
sns.barplot(scat,palette=['r','b','g','brown'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_9720\951812752.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(scat,palette=['r','b','g','brown'])
# <Axes: xlabel='Daypart', ylabel='Items'>

# %%
bar = bake.groupby('DayType')['Items'].count()

# %%
sns.barplot(bar)
# Out:
# <Axes: xlabel='DayType', ylabel='Items'>

# %%
plt.figure(figsize=(30,15))
sns.countplot(bake['Items'])
# Out:
# <Axes: xlabel='count', ylabel='Items'>
