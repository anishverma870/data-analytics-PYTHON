# %%
import pandas as pd
data = pd.read_clipboard()

# %%
data
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1        45.0          NaN        56.0    1.0      10
# 1           2         NaN         65.0        67.0    1.0      12
# 2           3        54.0         68.0        57.0    0.0      14
# 3           4        89.0         88.0         NaN    NaN      18
# 4           5         NaN         87.0        84.0    1.0      21

# %%
df_sklearn = data.copy()

# %%
df_pandas = data.copy()

# %%
df_sklearn_knn = data.copy()

# %%
import numpy as np

# %%
df_sklearn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1        45.0          NaN        56.0    1.0      10
# 1           2         NaN         65.0        67.0    1.0      12
# 2           3        54.0         68.0        57.0    0.0      14
# 3           4        89.0         88.0         NaN    NaN      18
# 4           5         NaN         87.0        84.0    1.0      21

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imp.fit(df_sklearn.iloc[:,1:2])
df_sklearn.iloc[:,1:2] = imputer.transform(df_sklearn.iloc[:,1:2])

# %%
df_sklearn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1   45.000000          NaN        56.0    1.0      10
# 1           2   62.666667         65.0        67.0    1.0      12
# 2           3   54.000000         68.0        57.0    0.0      14
# 3           4   89.000000         88.0         NaN    NaN      18
# 4           5   62.666667         87.0        84.0    1.0      21

# %%
df_sklearn.iloc[:,1:2]
# Out:
#    Marks 10th
# 0        45.0
# 1         NaN
# 2        54.0
# 3        89.0
# 4         NaN

# %%
df_sklearn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1   45.000000          NaN        56.0    1.0      10
# 1           2   62.666667         65.0        67.0    1.0      12
# 2           3   54.000000         68.0        57.0    0.0      14
# 3           4   89.000000         88.0         NaN    NaN      18
# 4           5   62.666667         87.0        84.0    1.0      21

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='median')
df_sklearn.iloc[:,2:4] = imp.fit_transform(df_sklearn.iloc[:,2:4])

# %%
df_sklearn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1   45.000000         77.5        56.0    1.0      10
# 1           2   62.666667         65.0        67.0    1.0      12
# 2           3   54.000000         68.0        57.0    0.0      14
# 3           4   89.000000         88.0        62.0    NaN      18
# 4           5   62.666667         87.0        84.0    1.0      21

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df_sklearn.iloc[:,4:5] = imp.fit_transform(df_sklearn.iloc[:,4:5])

# %%
df_sklearn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1   45.000000         77.5        56.0    1.0      10
# 1           2   62.666667         65.0        67.0    1.0      12
# 2           3   54.000000         68.0        57.0    0.0      14
# 3           4   89.000000         88.0        62.0    1.0      18
# 4           5   62.666667         87.0        84.0    1.0      21

# %%
df_pandas
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1        45.0          NaN        56.0    1.0      10
# 1           2         NaN         65.0        67.0    1.0      12
# 2           3        54.0         68.0        57.0    0.0      14
# 3           4        89.0         88.0         NaN    NaN      18
# 4           5         NaN         87.0        84.0    1.0      21

# %%
df_pandas['Marks 10th'] = df_pandas['Marks 10th'].fillna(df_pandas['Marks 10th'].mean())

# %%
df_pandas['Marks 12th '] = df_pandas['Marks 12th '].fillna(df_pandas['Marks 12th '].median())

# %%
df_pandas['Marks 12th '] = df_pandas['Marks 12th '].fillna(df_pandas['Marks 12th '].median())

# %%
df_pandas['Marks Grad'] = df_pandas['Marks Grad'].fillna(df_pandas['Marks Grad'].median())

# %%
#Explain Concept
df_pandas['State'] = df_pandas['State'].fillna(df_pandas['State'].mode()[0])

# %%
df_pandas
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1   45.000000         77.5        56.0    1.0      10
# 1           2   62.666667         65.0        67.0    1.0      12
# 2           3   54.000000         68.0        57.0    0.0      14
# 3           4   89.000000         88.0        62.0    1.0      18
# 4           5   62.666667         87.0        84.0    1.0      21

# %%
df_sklearn_knn
# Out:
#    Student ID  Marks 10th  Marks 12th   Marks Grad  State  Salary
# 0           1        45.0          NaN        56.0    1.0      10
# 1           2         NaN         65.0        67.0    1.0      12
# 2           3        54.0         68.0        57.0    0.0      14
# 3           4        89.0         88.0         NaN    NaN      18
# 4           5         NaN         87.0        84.0    1.0      21

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=1)
df_sklearn_knn = imputer.fit_transform(df_sklearn_knn)

# %%
df_sklearn_knn
# Out:
# array([[ 1., 45., 68., 56.,  1., 10.],
#        [ 2., 54., 65., 67.,  1., 12.],
#        [ 3., 54., 68., 57.,  0., 14.],
#        [ 4., 89., 88., 84.,  1., 18.],
#        [ 5., 89., 87., 84.,  1., 21.]])

# %%
df_sklearn_knn_2 = data.copy()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
df_sklearn_knn_2 = imputer.fit_transform(df_sklearn_knn_2)

# %%
pd.DataFrame(df_sklearn_knn_2,columns=['col1','col2','col3','col4','col5','col6'])
# Out:
#    col1  col2  col3  col4  col5  col6
# 0   1.0  45.0  66.5  56.0   1.0  10.0
# 1   2.0  49.5  65.0  67.0   1.0  12.0
# 2   3.0  54.0  68.0  57.0   0.0  14.0
# 3   4.0  89.0  88.0  75.5   1.0  18.0
# 4   5.0  71.5  87.0  84.0   1.0  21.0

# %%
outlier_data = pd.read_clipboard()

# %%
outlier_data
# Out:
#   Department  Age  Experience
# 0         HR   21           1
# 1         HR   33          12
# 2         IT   35          12
# 3         IT   36          12
# 4         HR   34          11
# 5         IT   33          13
# 6  Marketing   34          12
# 7         HR   32          10
# 8  Marketing   31           2
# 9         IT   55          35

# %%
def outlier_treatment(dataframe):
    numeric_df = dataframe.select_dtypes(include=['number'])

    Q1 = numeric_df.quantile(0.25)
    Q3 = numeric_df.quantile(0.75)
    IQR = Q3-Q1

    nonoutliers = ~((numeric_df<(Q1-1.5*IQR))|(numeric_df>(Q3+1.5*IQR))).any(axis=1)

    return dataframe[nonoutliers]

# %%
outlier_treatment(outlier_data)
# Out:
#   Department  Age  Experience
# 1         HR   33          12
# 2         IT   35          12
# 3         IT   36          12
# 4         HR   34          11
# 5         IT   33          13
# 6  Marketing   34          12
# 7         HR   32          10

# %%
outlier_data['Age'].quantile(0.75)
# Out:
# 34.75

# %% [markdown]
# # Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://books.toscrape.com/'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
books = soup.find_all("article",class_ = "product_pod")

# %%
books
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
data = []

for book in books:
    title = book.h3.a['title']
    price = book.find("p",class_="price_color").text
    availability = book.find("p", class_="instock availability").text.strip()
    data.append({"Title":title, "Price":price, "Availability":availability})

data
# Out:
# [{'Title': 'A Light in the Attic',
#   'Price': '£51.77',
#   'Availability': 'In stock'},
#  {'Title': 'Tipping the Velvet',
#   'Price': '£53.74',
#   'Availability': 'In stock'},
#  {'Title': 'Soumission', 'Price': '£50.10', 'Availability': 'In stock'},
#  {'Title': 'Sharp Objects', 'Price': '£47.82', 'Availability': 'In stock'},
#  {'Title': 'Sapiens: A Brief History of Humankind',
#   'Price': '£54.23',
#   'Availability': 'In stock'},
#  {'Title': 'The Requiem Red', 'Price': '£22.65', 'Availability': 'In stock'},
#  {'Title': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'Price': '£33.34',
#   'Availability': 'In stock'},
#  {'Title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'Price': '£17.93',
#   'Availability': 'In stock'},
#  {'Title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'Price': '£22.60',
#   'Availability': 'In stock'},
# ...

# %%
pd.DataFrame(data).to_csv('My_books.csv',index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rahul\\Downloads'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL template
base_url = "http://books.toscrape.com/catalogue/page-{}.html"

# Placeholder for all books
all_books = []

# Loop through all 50 pages
for page in range(1, 51):
    print(f"Scraping Page {page}...")
    url = base_url.format(page)
    response = requests.get(url)
    
    # If status not OK, break (safety check)
    if response.status_code != 200:
        print("Page not found. Stopping...")
        break

    soup = BeautifulSoup(response.content, "html.parser")
    books = soup.find_all("article", class_="product_pod")

    for book in books:
        title = book.h3.a['title']
        price = book.find("p", class_="price_color").text
        availability = book.find("p", class_="instock availability").text.strip()

        all_books.append({
            "Title": title,
            "Price": price,
            "Availability": availability
        })

# Save all books to CSV
df = pd.DataFrame(all_books)
df.to_csv("all_books.csv", index=False)
print("✅ Scraping complete. Data saved to 'all_books.csv'")
# Out:
# Scraping Page 1...
# Scraping Page 2...
# Scraping Page 3...
# Scraping Page 4...
# Scraping Page 5...
# Scraping Page 6...
# Scraping Page 7...
# Scraping Page 8...
# Scraping Page 9...
# Scraping Page 10...
# Scraping Page 11...
# Scraping Page 12...
# Scraping Page 13...
# Scraping Page 14...
# Scraping Page 15...
# Scraping Page 16...
# Scraping Page 17...
# Scraping Page 18...
# Scraping Page 19...
# Scraping Page 20...
# Scraping Page 21...
# Scraping Page 22...
# Scraping Page 23...
# Scraping Page 24...
# Scraping Page 25...
# Scraping Page 26...
# Scraping Page 27...
# Scraping Page 28...
# Scraping Page 29...
# Scraping Page 30...
# Scraping Page 31...
# Scraping Page 32...
# Scraping Page 33...
# Scraping Page 34...
# Scraping Page 35...
# Scraping Page 36...
# Scraping Page 37...
# Scraping Page 38...
# Scraping Page 39...
# Scraping Page 40...
# Scraping Page 41...
# Scraping Page 42...
# Scraping Page 43...
# Scraping Page 44...
# Scraping Page 45...
# ...

# %%
data = []

for book in books:
    title = book.h3.a['title']
    img = book.find("div", class_="image_container")
    price = book.find("p",class_="price_color").text
    availability = book.find("p", class_="instock availability").text.strip()
    data.append({"Title":title,"img":img, "Price":price, "Availability":availability})

data
# Out:
# [{'Title': 'Frankenstein',
#   'img': <div class="image_container">
#   <a href="frankenstein_20/index.html"><img alt="Frankenstein" class="thumbnail" src="../media/cache/00/25/0025515e987a1ebd648773f9ac70bfe6.jpg"/></a>
#   </div>,
#   'Price': '£38.00',
#   'Availability': 'In stock'},
#  {'Title': 'Forever Rockers (The Rocker #12)',
#   'img': <div class="image_container">
#   <a href="forever-rockers-the-rocker-12_19/index.html"><img alt="Forever Rockers (The Rocker #12)" class="thumbnail" src="../media/cache/7f/b0/7fb03a053c270000667a50dd8d594843.jpg"/></a>
#   </div>,
#   'Price': '£28.80',
#   'Availability': 'In stock'},
#  {'Title': 'Fighting Fate (Fighting #6)',
#   'img': <div class="image_container">
#   <a href="fighting-fate-fighting-6_18/index.html"><img alt="Fighting Fate (Fighting #6)" class="thumbnail" src="../media/cache/57/e2/57e255929f6e597c18cb3843904cd92b.jpg"/></a>
#   </div>,
#   'Price': '£39.24',
#   'Availability': 'In stock'},
#  {'Title': 'Emma',
# ...

# %%
youtube = requests.get('https://www.youtube.com/')

# %%
youtube
# Out:
# <Response [200]>

# %%
youtube.content
# Out:
# b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="w7agnmQavqTmD9_cLYTPmA">window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20250415.08_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"725719775":false,"513659523":false,"568333945":false,"1331761403":false,"651175828":false,"722764542":false,"1981196515":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLC
# ...

# %% [markdown]
# # End
