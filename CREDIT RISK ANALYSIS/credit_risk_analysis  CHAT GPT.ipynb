# %% [markdown]
# # **DATA PREPERATION**

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
inp0 = pd.read_csv(r'/content/drive/MyDrive/DATASET/application_data.csv')

# %%
inp1 = pd.read_csv(r'/content/drive/MyDrive/DATASET/previous_application.csv')

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
inp0.head(2)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
#
#    AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0         351000.0   Unaccompanied          Working
# 1        1129500.0          Family    State servant
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special  Single / not married  House / apartment
# 1               Higher education               Married  House / apartment
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# ...

# %%
inp1.head(2)
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# 1                       11                           Y
#
#    NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  \
# 0                       1                0.0               0.182832
# 1                       1                NaN                    NaN
#
#    RATE_INTEREST_PRIVILEGED NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  \
# ...

# %%
#inp0.isnull().mean()*100

# %%
#inp1.isnull().mean()*100

# %%
#inp0.dtypes

# %%
#inp1.dtypes

# %%
inp0['CODE_GENDER'] = inp0['CODE_GENDER'].replace('XNA',inp0['CODE_GENDER'].mode()[0]) #MSSING

# %%
inp0['CNT_CHILDREN'] = pd.cut(inp0['CNT_CHILDREN'],
                                  bins=[-1, 0, 1, 2, 3, 4, np.inf],
                                  labels=['0', '1', '2', '3', '4', '5+'])    #group

# %%
inp0['CNT_FAM_MEMBERS'].fillna(inp0['CNT_FAM_MEMBERS'].mode()[0],inplace=True) # MISSING

# %%
inp0['NAME_TYPE_SUITE'].fillna(inp0['NAME_TYPE_SUITE'].mode()[0],inplace=True) # MISSING

# %%
inp0.AMT_ANNUITY.fillna(inp0.AMT_ANNUITY.median(),inplace=True) # MISSING

# %%
inp0.AMT_GOODS_PRICE.fillna(inp0.AMT_GOODS_PRICE.median(),inplace=True) # MISSING

# %%
inp0.OWN_CAR_AGE.fillna(0,inplace=True) # MISSING

# %%
inp0['OCCUPATION_TYPE'].fillna('Unknown',inplace=True) # MISSING

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
inp0[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']] = imputer.fit_transform(inp0[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']]) #MISSING

# %%
inp0['EXT_SOURCE_MEAN'] = inp0[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'TARGET']].mean(axis=1) #standardization

# %%
null_condition = (inp0.isna().mean() * 100 > 46) & (inp0.isna().mean() * 100 < 70)
true_columns = inp0.columns[null_condition]                                         # MISSING
true_columns
# Out:
# Index(['APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG',
#        'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG',
#        'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG',
#        'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG',
#        'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE',
#        'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE',
#        'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE',
#        'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE',
#        'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI',
#        'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI',
#        'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI',
#        'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI',
#        'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI',
# ...

# %%
for col in true_columns:
  if col in inp0.columns:
    inp0[col].fillna(inp0[col].mode()[0],inplace=True)   #MISSING

# %%
#inp0.isnull().mean()*100

# %%
#inp0['OBS_30_CNT_SOCIAL_CIRCLE'].value_counts()

# %%
#inp0['DEF_30_CNT_SOCIAL_CIRCLE'].describe()

# %%
#inp0['OBS_60_CNT_SOCIAL_CIRCLE'].describe()

# %%
#inp0['DEF_60_CNT_SOCIAL_CIRCLE'].describe()

# %%
def cap_outliers(df, columns):
    df_capped = df.copy()

    for column in columns:
        Q1 = df_capped[column].quantile(0.25)
        Q3 = df_capped[column].quantile(0.75)
        IQR = Q3 - Q1

        if IQR == 0:
            continue  # Skip capping if there's no variation

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        df_capped[column] = df_capped[column].apply(lambda x:
            lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

    return df_capped

# %%
columns_to_treat = ['OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE']
df_cleaned = cap_outliers(inp0, columns_to_treat)                                                  # OUTLIER

# %%
inp0 = df_cleaned

# %%
inp0.shape
# Out:
# (307511, 123)

# %%
for col in columns_to_treat:
  if col in inp0.columns:
    inp0[col] = inp0[col].fillna(inp0[col].median())                                                 # MISSING

# %%
inp0['AMT_REQ_CREDIT_BUREAU_QRT'].value_counts()                                                     # founded one outlier
# Out:
# AMT_REQ_CREDIT_BUREAU_QRT
# 0.0      215417
# 1.0       33862
# 2.0       14412
# 3.0        1717
# 4.0         476
# 5.0          64
# 6.0          28
# 8.0           7
# 7.0           7
# 261.0         1
# 19.0          1
# Name: count, dtype: int64

# %%
Q1 = inp0['AMT_REQ_CREDIT_BUREAU_QRT'].quantile(0.25)
Q3 = inp0['AMT_REQ_CREDIT_BUREAU_QRT'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace specific values
inp0['AMT_REQ_CREDIT_BUREAU_QRT'] = inp0['AMT_REQ_CREDIT_BUREAU_QRT'].replace({261.0: upper_bound, 19.0: upper_bound})    #OUTLIER

# %%
amt_req =['AMT_REQ_CREDIT_BUREAU_HOUR','AMT_REQ_CREDIT_BUREAU_WEEK','AMT_REQ_CREDIT_BUREAU_DAY','AMT_REQ_CREDIT_BUREAU_MON','AMT_REQ_CREDIT_BUREAU_QRT','AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
for col in amt_req:
  if col in inp0.columns:
    inp0[col] = inp0[col].fillna(inp0[col].median())           #MISSING VALUE

# %%
inp0.dropna(subset=['DAYS_LAST_PHONE_CHANGE'],inplace=True)           MISSING

# %%
inp0['CODE_GENDER'] = inp0['CODE_GENDER'].map({'F':'FEMALE','M':'MALE','XNA':'XNA'})                     #standard

# %%
inp0['TARGET'] = inp0['TARGET'].map({0:'Non-Defaulter',1:'Defaulter'})                                #standard

# %%
inp1.drop(columns=['RATE_INTEREST_PRIMARY','RATE_INTEREST_PRIVILEGED'],axis=1,inplace=True)           #missing

# %%
inp1.drop(columns=['AMT_DOWN_PAYMENT'],inplace=True)                                                 #missing

# %%
inp1['AMT_ANNUITY'].fillna(inp1['AMT_ANNUITY'].median(),inplace=True)                               #missing

# %%
inp1['NAME_TYPE_SUITE'].fillna(inp1['NAME_TYPE_SUITE'].mode()[0],inplace=True)                      #MISSING

# %%
inp1['AMT_GOODS_PRICE'].fillna(0,inplace=True)  # i think it shall be fill with the zero                #MISSING

# %%
inp1['RATE_DOWN_PAYMENT'].fillna(inp1['RATE_DOWN_PAYMENT'].mode()[0],inplace=True)                    #MISSING

# %%
inp1['CNT_PAYMENT'].fillna(inp1['CNT_PAYMENT'].mode()[0],inplace=True)             # MISSING

# %%
null_day = ['DAYS_FIRST_DRAWING',
'DAYS_FIRST_DUE',
'DAYS_LAST_DUE_1ST_VERSION',
'DAYS_LAST_DUE',
'DAYS_TERMINATION'
]

# %%
for col in null_day:
  if col in inp1:
    inp1[col].fillna( 365243,inplace=True)                                                              # MISSING

# %%
inp1['NFLAG_INSURED_ON_APPROVAL'].value_counts()
# Out:
# NFLAG_INSURED_ON_APPROVAL
# 0.0    665527
# 1.0    331622
# Name: count, dtype: int64

# %%
inp1['NFLAG_INSURED_ON_APPROVAL'].fillna(inp1['NFLAG_INSURED_ON_APPROVAL'].mode()[0],inplace=True)  #MISSING

# %%
inp1['PRODUCT_COMBINATION'].fillna(inp1['PRODUCT_COMBINATION'].mode()[0],inplace=True)             #MISSING

# %%
inp1['AMT_CREDIT'].fillna(inp1['AMT_CREDIT'].median(),inplace=True)                                #MISSING

# %%
# standardization

# %%
data_type = ['DAYS_BIRTH',	'DAYS_EMPLOYED',	'DAYS_REGISTRATION',	'DAYS_ID_PUBLISH']
for col in data_type:
  if col in inp0.columns:                                                                   #standard INP0
    inp0[col] = inp0[col].astype(float)

# %%
inp0[['DAYS_BIRTH',	'DAYS_EMPLOYED',	'DAYS_REGISTRATION',	'DAYS_ID_PUBLISH']].dtypes
# Out:
# DAYS_BIRTH           float64
# DAYS_EMPLOYED        float64
# DAYS_REGISTRATION    float64
# DAYS_ID_PUBLISH      float64
# dtype: object

# %%
for col in data_type:                                                                      #STANDARDIZATION
  if col in inp0.columns:
    inp0[col] = -inp0[col]//365

# %%
#inp0[['DAYS_BIRTH',	'DAYS_EMPLOYED',	'DAYS_REGISTRATION',	'DAYS_ID_PUBLISH']].value_counts()

# %%
flag_columns = [col for col in inp0.columns if col.startswith('FLAG_')]                 #STANDARDIZATION

# %%
flag_columns.remove('FLAG_OWN_CAR')
flag_columns.remove('FLAG_OWN_REALTY')                                                    #STANDARDIZATION

# %%
for col in flag_columns:
  if col in inp0.columns:                                                                 #STANDARDIZATION
    inp0[col] = inp0[col].map({0:'NO',1:'YES'})

# %%
inp0[['FLAG_OWN_CAR','FLAG_OWN_REALTY'	]] = inp0[['FLAG_OWN_CAR','FLAG_OWN_REALTY'	]].applymap({'N':'NO','Y':'YES'}.get)                                 # STANDARDIZATION

# %%
reg_col  = ['REG_REGION_NOT_LIVE_REGION',	'REG_REGION_NOT_WORK_REGION',	'LIVE_REGION_NOT_WORK_REGION',	'REG_CITY_NOT_LIVE_CITY',	'REG_CITY_NOT_WORK_CITY',	'LIVE_CITY_NOT_WORK_CITY']
for col in reg_col:
  if col in inp0.columns:
    inp0[col] = inp0[col].map({0:'NO',1:'YES'})                                                                                  # STANDARDIZATION

# %%
inp1.replace({'XNA': np.nan, 'XAP': np.nan, 'XNA XAP': np.nan}, inplace=True)                    #STANDARDIZATION

# %%
inp1['NAME_CASH_LOAN_PURPOSE'].fillna('Unknown',inplace=True)       #MISSING

# %%
inp1['CODE_REJECT_REASON'].fillna('Unknown',inplace=True)                                       #MISSING

# %%
inp1['NAME_CONTRACT_TYPE'].fillna(inp1['NAME_CONTRACT_TYPE'].mode()[0],inplace=True)                     #MISSING

# %%
inp1['NAME_PAYMENT_TYPE'].fillna(inp1['NAME_PAYMENT_TYPE'].mode()[0],inplace=True)                               #MISSING

# %%
inp1['NAME_CLIENT_TYPE'].fillna(inp1['NAME_CLIENT_TYPE'].mode()[0],inplace=True)                                    #MISSING

# %%
inp1['NAME_GOODS_CATEGORY'].fillna(inp1['NAME_GOODS_CATEGORY'].mode()[0],inplace=True)                               #MISSING

# %%
inp1['NAME_PRODUCT_TYPE'].fillna(inp1['NAME_PRODUCT_TYPE'].mode()[0],inplace=True)                                    #MISSING

# %%
inp1['NAME_SELLER_INDUSTRY'].fillna(inp1['NAME_SELLER_INDUSTRY'].mode()[0],inplace=True)                               #MISSING

# %%
inp1['NAME_YIELD_GROUP'].fillna(inp1['NAME_YIELD_GROUP'].mode()[0],inplace=True)                                        #MISSING

# %%
inp1['NAME_PORTFOLIO'].fillna(inp1['NAME_PORTFOLIO'].mode()[0],inplace=True)                                            #MISSING

# %% [markdown]
# # **STANDARDIZATION**

# %%
inp1.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0          17145.0                   SATURDAY
# 1    679671.0         607500.0                   THURSDAY
# 2    136444.5         112500.0                    TUESDAY
# 3    470790.0         450000.0                     MONDAY
# 4    404055.0         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# 0                       15                           Y
# ...

# %%
inp1['FLAG_LAST_APPL_PER_CONTRACT'] = inp1['FLAG_LAST_APPL_PER_CONTRACT'].map({'N':'NO','Y':'YES'})               # STANDARDIZATION

# %%
inp1['NFLAG_LAST_APPL_IN_DAY'] = inp1['NFLAG_LAST_APPL_IN_DAY'].map({1:'YES',0:'NO'})                                 # STANDARDIZATION

# %%
inp1['DAYS_DECISION'] = inp1['DAYS_DECISION'].astype(float)                                                              # STANDARDIZATION

# %%
# List of columns
days_col = ['DAYS_DECISION','DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION',
            'DAYS_LAST_DUE', 'DAYS_TERMINATION']

for col in days_col:
    if col in inp1.columns:
        # Create new column with cleaned values (positive or 'missing')
        def format_days(val):
            if val == 365243:
                return 'Missing'
            else:
                return f'{abs(val)} days'

        inp1[col + '_CLEAN'] = inp1[col].apply(format_days)
                                                                                                                        # STANDARDIZATION

# %%
inp1.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0          17145.0                   SATURDAY
# 1    679671.0         607500.0                   THURSDAY
# 2    136444.5         112500.0                    TUESDAY
# 3    470790.0         450000.0                     MONDAY
# 4    404055.0         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT NFLAG_LAST_APPL_IN_DAY  \
# 0                       15                         YES                    YES
# ...

# %%
plt.figure(figsize=(5,2))
sns.countplot(data = inp0,x='TARGET')
plt.show()

# %%
sns.histplot(data=inp0,x='NAME_CONTRACT_TYPE')
# Out:
# <Axes: xlabel='NAME_CONTRACT_TYPE', ylabel='Count'>

# %%
sns.countplot(data=inp0,x='CODE_GENDER')
# Out:
# <Axes: xlabel='CODE_GENDER', ylabel='count'>

# %%
sns.histplot(data=inp0,x='CNT_CHILDREN')
# Out:
# <Axes: xlabel='CNT_CHILDREN', ylabel='Count'>

# %%
sns.histplot(data=inp0,x='NAME_TYPE_SUITE')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Unaccompanied'),
#   Text(1, 0, 'Family'),
#   Text(2, 0, 'Spouse, partner'),
#   Text(3, 0, 'Children'),
#   Text(4, 0, 'Other_A'),
#   Text(5, 0, 'Other_B'),
#   Text(6, 0, 'Group of people')])
